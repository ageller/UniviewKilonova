# %% [markdown]
# # Testing Spiral
#
# *Aaron Geller 2018*

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %matplotlib notebook

# %%
a = 0.1
b = 0.1
c = 1.
Nturns = 2


theta = np.linspace(0,5.*np.pi, 1000)
r = a + b*th**(1./c)

x = r*np.cos(theta)
y = r*np.sin(theta)

f,ax = plt.subplots()
ax.plot(x,y)
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N = 100
xx = np.linspace(-1, 1, N)
yy = np.linspace(-1, 1, N)
xv, yv = np.meshgrid(xx, yy)

z = np.zeros((N, N))
for i,xa in enumerate(xx):
    for j,ya in enumerate(yy):
        dist = (xa - x)**2. + (ya - y)**2.
        z[i,j] = min(dist**0.5)
#z = np.sin(xv**2 + yv**2) / (xv**2 + yv**2)
f,ax = plt.subplots()
levels = np.linspace(0,1,100)
h = ax.contourf(xx,yy,z, levels=levels, norm = LogNorm())
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
